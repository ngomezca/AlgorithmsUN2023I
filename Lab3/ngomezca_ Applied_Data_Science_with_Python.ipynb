# %% [markdown]
# ### Laboratory 3

# %% [markdown]
# # LinkeIn link:
#
# https://www.linkedin.com/in/nicol%C3%A1s-g%C3%B3mez-castillo-40a9ba18b/

# %% [markdown]
# ![LinkedInProfile.png](attachment:c4ff7d77-d09d-48f8-9a4e-a0e80ccf5627.png)

# %% [markdown]
# ![ngomezcacognitiveclasspython101fordatascience.png](attachment:538d5dbb-199e-4db5-9f34-ac38342ca62a.png)

# %% [markdown]
# ![ngomezcacognitiveclassdataanalysiswithpython.png](attachment:f966c12c-4b9a-46da-a0b2-56db56fdd14f.png)

# %% [markdown]
# ![ngomezcacognitiveclassdatavisualizationwithpython.png](attachment:94fd3249-ae29-4cb9-915f-82d163f52951.png)
